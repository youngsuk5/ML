# %% [markdown]
# <a href="https://colab.research.google.com/github/youngsuk5/ML/blob/main/Linear/ElasticNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 보스턴 주택 가격에 대한 신축망

# %%
from sklearn.linear_model import ElasticNet
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

# %%
X, y = load_boston(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
#l1_ratio = 0 (L2 규제만 사용).
#l1_ratio = 1 (L1 규제만 사용).
#0 < l1_ratio < 1 (L1 and L2 규제의 혼합사용)
model = ElasticNet(alpha=0.01, l1_ratio=0.5)
model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
print('학습 데이터 점수 :', model.score(X_train, y_train))
print('평가 데이터 점수 :', model.score(X_test, y_test))
# Out:
# 학습 데이터 점수 : 0.7301074501398588
# 평가 데이터 점수 : 0.7365459780483674

# %%
import matplotlib.pyplot as plt

def plot_boston_prices(expected, predicted):
   plt.figure(figsize=(8, 4))
   plt.scatter(expected, predicted)
   plt.plot([0, 50], [0, 50], '--r')
   plt.xlabel('True price ($100,000s')
   plt.ylabel('Predicted price ($100,000s')
   plt.tight_layout()

predicted = model.predict(X_test)
expected = y_test
plot_boston_prices(expected, predicted)

# %% [markdown]
# 캘리포니아 주택 가격에 대한 신축망

# %%
from sklearn.datasets import fetch_california_housing

california = fetch_california_housing()

X_train, X_test , y_train, y_test = train_test_split(california.data, california.target, test_size=0.2)
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to /root/scikit_learn_data

# %%
model = ElasticNet(alpha=0.01, l1_ratio=0.5)
model.fit(X_train, y_train)
# Out:
# ElasticNet(alpha=0.01, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
print('학습 데이터 점수 :', model.score(X_train, y_train))
print('평가 데이터 점수 :', model.score(X_test, y_test))
# Out:
# 학습 데이터 점수 : 0.6021382903815484
# 평가 데이터 점수 : 0.6124554025527311

# %%
def plot_california_prices(expected, predicted):
   plt.figure(figsize=(8, 4))
   plt.scatter(expected, predicted)
   plt.plot([0, 5], [0, 5], '--r')
   plt.xlabel('True price ($100,000s')
   plt.ylabel('Predicted price ($100,000s')
   plt.tight_layout()

predicted = model.predict(X_test)
expected = y_test
plot_california_prices(expected, predicted)
